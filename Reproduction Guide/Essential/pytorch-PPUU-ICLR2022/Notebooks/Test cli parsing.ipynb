# %%
from omegaconf import OmegaConf, MISSING
import dataclasses

from ppuu import configs
from ppuu import eval_mpc_fm

Type = eval_mpc_fm.EvalMPCConfig

@dataclasses.dataclass 
class A(configs.ConfigBase):
    a : int = 3
    b : bool = True
        
@dataclasses.dataclass 
class B(configs.ConfigBase):
    d : A = A()
    b : bool = True

# %%
print(B())
# Out:
# B(d=A(a=3, b=True), b=True)

# %%
configs.combine_dataclass_dict(B(), {'d.b': '123'})
# Out:
# /home/us441/vlad/miniconda3/envs/forked/lib/python3.8/site-packages/omegaconf/omegaconf.py:572: UserWarning: update() merge flag is is not specified, defaulting to False.
# For more details, see https://github.com/omry/omegaconf/issues/367
#   warnings.warn(
# B(d=A(a=3, b='123'), b=True)

# %%
dcls = Type()
config_base = OmegaConf.create(dataclasses.asdict(dcls))
config_new = OmegaConf.from_dotlist(list(c_dict))
for k, v in c_dict.items():
    OmegaConf.update(config_base, k, v)
print(config_base)
# OmegaConf.to_container(config_together)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-64831c683700> in <module>
#       1 dcls = Type()
#       2 config_base = OmegaConf.create(dataclasses.asdict(dcls))
# ----> 3 config_new = OmegaConf.from_dotlist(list(c_dict))
#       4 for k, v in c_dict.items():
#       5     OmegaConf.update(config_base, k, v)
#
# NameError: name 'c_dict' is not defined

# %%
config_together
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3b6f58af0f4b> in <module>
# ----> 1 config_together
#
# NameError: name 'config_together' is not defined
