# %%
path1 = '/misc/vlgscratch4/LecunGroup/nvidia-collab/traffic-data_offroad/state-action-cost/data_i80_v0/splits.pth'
path2 = '/home/us441/work/splits.pth'
path3 = '/misc/vlgscratch4/LecunGroup/nvidia-collab/vlad/traffic-data/state-action-cost/data_i80_v0/splits.pth'

# %%
import torch

# %%
s1 = torch.load(path1)
s2 = torch.load(path2)
s3 = torch.load(path3)

# %%
(s1['test_indx'] == s3['test_indx']).all()
# Out:
# True

# %%
s2['test_indx'][:10]
# Out:
# array([ 447,  709, 1924, 1221, 3922, 2766,  387, 3547, 1337, 4850])
